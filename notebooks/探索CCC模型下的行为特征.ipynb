# %%
# 导入数据
read.csv("/Users/dddd1007/project2git/cognitive_control_model/data/output/summary/subdata_with_CCC.csv")
# Out:
#       stim_color stim_loc Type Response RT    Subject         Trial
# 1     1          0        1    0        503.8 sub25_LuSihan    1
# 2     1          0        1    0        604.8 sub25_LuSihan    2
# 3     0          0        1    1        545.8 sub25_LuSihan    3
# 4     0          1        1    1        534.7 sub25_LuSihan    4
# 5     1          0        1    0        621.6 sub25_LuSihan    5
# 6     1          0        1    0        570.5 sub25_LuSihan    6
# 7     0          0        1    1        451.6 sub25_LuSihan    7
# 8     0          1        1    1        552.5 sub25_LuSihan    8
# 9     1          0        1    0        445.6 sub25_LuSihan    9
# 10    1          0        1    0        436.5 sub25_LuSihan   10
# 11    0          1        1    1        409.5 sub25_LuSihan   11
# 12    0          0        1    1        480.3 sub25_LuSihan   12
# 13    1          0        1    0        465.3 sub25_LuSihan   13
# ...
